# %%
from twython import * 
import sys
import csv

# %%
latitude = 41.881832    # geographical centre of search
longitude = -87.623177    # geographical centre of search
max_range = '10km'             # search range in kilometres
num_results = 50        # minimum results to obtain
outfile = "output.csv"

# %%
creds = {"key": "wpiguCOYUnaewpZJNoMVuumwR", "secret": "G5Fzh4IGGfr3LQNbeD8UVu4st281I0MtktI6H2nFilWlinDxqw"}

# %%
python_tweets = Twython(creds['key'], creds['secret'])

# %%
a = 'geocode:{},{},{}'.format(latitude,longitude,max_range)
a
# Out:
# 'geocode:41.881832,-87.623177,10km'

# %%
query = {'q': '',
         'geocode': '41.881832,-87.623177,1km',
        'result_type': 'popular',
        'count': 10,
        'lang': 'en',
        }
query
# Out:
# {'q': '',
#  'geocode': '41.881832,-87.623177,1km',
#  'result_type': 'popular',
#  'count': 10,
#  'lang': 'en'}

# %%
dict_ = {'user': [], 'date': [], 'text': [], 'favorite_count': []}  
for status in python_tweets.search(**query)['statuses']:  
    dict_['user'].append(status['user']['screen_name'])
    dict_['date'].append(status['created_at'])
    dict_['text'].append(status['text'])
    dict_['favorite_count'].append(status['favorite_count'])

# %%
dict_
# Out:
# {'user': [], 'date': [], 'text': [], 'favorite_count': []}

# %%
# search_results = python_tweets.search(q="hurricane", geocode='41.881832,-87.623177,1km', result_type='news')
search_results = python_tweets.search( q="hurricane harvey",result_type='news')

# %%
search_results
# Out:
# {'statuses': [{'created_at': 'Thu May 02 15:09:22 +0000 2019',
#    'id': 1123967723594293248,
#    'id_str': '1123967723594293248',
#    'text': 'RT @EricBlake12: #Fani is unfortunately looking quite powerful this morning- roughly a supertyphoon or category 4 (US) hurricane intensity.…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Fani', 'indices': [17, 22]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'EricBlake12',
#       'name': 'Eric Blake 🌀',
#       'id': 912858588,
#       'id_str': '912858588',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 24457070,
# ...

# %%
search_results['statuses']
# Out:
# [{'created_at': 'Thu May 02 15:09:22 +0000 2019',
#   'id': 1123967723594293248,
#   'id_str': '1123967723594293248',
#   'text': 'RT @EricBlake12: #Fani is unfortunately looking quite powerful this morning- roughly a supertyphoon or category 4 (US) hurricane intensity.…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'Fani', 'indices': [17, 22]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'EricBlake12',
#      'name': 'Eric Blake 🌀',
#      'id': 912858588,
#      'id_str': '912858588',
#      'indices': [3, 15]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 24457070,
#    'id_str': '24457070',
# ...
