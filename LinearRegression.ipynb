# %%
import pandas as pd
import numpy as np
from os import path

# %%
fname = path.expanduser('/home/suraj/Workspace/Python-Misc/Bike-Sharing-Dataset/day.csv')

# %%
df = pd.read_csv(fname)
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df.shape
# Out:
# (731, 16)

# %%
df.cnt.shape
# Out:
# (731,)

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# 6          7  2011-01-07       1   0     1        0        5           1
# 7          8  2011-01-08       1   0     1        0        6           0
# 8          9  2011-01-09       1   0     1        0        0           0
# 9         10  2011-01-10       1   0     1        0        1           1
# 10        11  2011-01-11       1   0     1        0        2           1
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df, df.cnt, test_size=0.2, random_state=0)

# %%
X_train.head
# Out:
# <bound method NDFrame.head of      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 97        98  2011-04-08       2   0     4        0        5           1
# 503      504  2012-05-18       2   1     5        0        5           1
# 642      643  2012-10-04       4   1    10        0        4           1
# 498      499  2012-05-13       2   1     5        0        0           0
# 303      304  2011-10-31       4   0    10        0        1           1
# 570      571  2012-07-24       3   1     7        0        2           1
# 250      251  2011-09-08       3   0     9        0        4           1
# 17        18  2011-01-18       1   0     1        0        2           1
# 595      596  2012-08-18       3   1     8        0        6           0
# 240      241  2011-08-29       3   0     8        0        1           1
# 547      548  2012-07-01       3   1     7        0        0           0
# ...

# %%
Y_train
